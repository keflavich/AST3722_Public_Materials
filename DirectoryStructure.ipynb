# %% [markdown]
# # Navigating Directory Structures
#
#
# Files on your computer are stored in a file system made up of directories, also known as folders.
#
#
# Folders (or directories) are things that can hold either files of any type (like ipython notebooks or FITS files) or other folders.
#
# Folders usually do not have any _extension_ - they will just be a name with no `.x` at the end.  Extensions are the `.ipynb`, `.fits`, `.FIT`, `.py` text at the end of a file's name; they tell you what type of file they are.

# %% [markdown]
# There are many ways to navigate the file system.
#
# You can do it graphically:
#
#  * On Windows, you use Windows Explorer.
#  * On Mac, you use Finder
#  * On Linux, there are many options - usually they'll be indicated by a manila folder icon
#
# In these graphical interfaces, folders are usually indicated by manila folder icons (google "manila folder" if you're not familiar with these)

# %% [markdown]
# ## Python filesystem navigation
#
# This notebook will show you how to navigate the filesystem using python alone.
#
# We'll use the `os` toolkit primarily, which has several functions we'll explore.

# %%
import os

# %% [markdown]
# The first question you can ask with a file system is, "where are we now?"
#
# You do this with `os.getcwd`, which is shorthand for "Get current working directory"

# %%
# (we're saving the starting point in a variable for later use)
starting_cwd = os.getcwd()
starting_cwd
# Out:
# '/home/runner/work/AST3722_Public_Materials/AST3722_Public_Materials/executed.workdir'

# %% [markdown]
# Any files that are in _this_ directory can be "accessed" just by their filenames (we'll get into what that means more soon)

# %% [markdown]
# The files in _this_ directory, the current (or present) working directory (`cwd` or `pwd`), can be listed with the `listdir` command:

# %%
os.listdir()
# Out:
# ['Planet Observation Planning.ipynb',
#  'EXECUTED_BRANCH.md',
#  'notebooks.toml',
#  'LongOrShortAnswerKey.ipynb',
#  '.gitignore',
#  'DataReduction_SingleFrame_exercise_filled.ipynb',
#  'Observation Planning Part 3 Exercise.ipynb',
#  'DirectoryStructure.ipynb',
#  'DataReductionWalkthrough.ipynb',
#  'Observation Planning Exercise.ipynb',
#  'SNR Investigation Continued.ipynb',
#  'Observation Planning Part 2.ipynb',
#  'Fitting - Simple Version.ipynb',
#  'Long Exposures or Short Exposures.ipynb',
#  'Observation Planning.ipynb',
#  'Detector Characterization (CCD) - Bias and Darks.ipynb',
#  'tests',
#  '.github',
#  'Observation Planning Part 3.ipynb',
#  'tools',
#  'README.md',
#  'Detector Characterization (CMOS) - Bias, Darks, Gain, Flats.ipynb',
#  'AltAzcalculations.ipynb',
#  'CCDs Overview - Data Reduction.ipynb',
#  'requirements-test.txt',
#  'requirements.txt',
#  'MachineReadableTables.ipynb',
#  'CCDs - Photon Count Statistics.ipynb',
#  'CCDs - Count Statistics - Exercise.ipynb',
#  'SNR Investigation Continued (answer key 1).ipynb',
#  'CCDReductionLabExercise.ipynb',
#  'Shifting.ipynb',
#  'DataReduction_SingleFrame_exercise.ipynb',
#  'pytest.ini',
#  'SNR Investigation Continued (answer key two).ipynb',
#  'Observation Planning - Space-Based.ipynb',
#  'Observation Planning Part 2 Exercise.ipynb',
#  'Observation Planning - Space-based - Exercise.ipynb']

# %% [markdown]
# What you see when you do this depends on what's there.
#
# We can write to a file in this directory:

# %%
with open('new_file.txt', 'w') as fh:
    fh.write("This is a new file")

# %% [markdown]
# And now there will be a file called `new_file.txt` when we run `os.listdir` again:

# %%
os.listdir()
# Out:
# ['Planet Observation Planning.ipynb',
#  'EXECUTED_BRANCH.md',
#  'notebooks.toml',
#  'LongOrShortAnswerKey.ipynb',
#  '.gitignore',
#  'DataReduction_SingleFrame_exercise_filled.ipynb',
#  'Observation Planning Part 3 Exercise.ipynb',
#  'DirectoryStructure.ipynb',
#  'DataReductionWalkthrough.ipynb',
#  'Observation Planning Exercise.ipynb',
#  'SNR Investigation Continued.ipynb',
#  'Observation Planning Part 2.ipynb',
#  'Fitting - Simple Version.ipynb',
#  'Long Exposures or Short Exposures.ipynb',
#  'Observation Planning.ipynb',
#  'Detector Characterization (CCD) - Bias and Darks.ipynb',
#  'tests',
#  '.github',
#  'Observation Planning Part 3.ipynb',
#  'tools',
#  'README.md',
#  'Detector Characterization (CMOS) - Bias, Darks, Gain, Flats.ipynb',
#  'AltAzcalculations.ipynb',
#  'new_file.txt',
#  'CCDs Overview - Data Reduction.ipynb',
#  'requirements-test.txt',
#  'requirements.txt',
#  'MachineReadableTables.ipynb',
#  'CCDs - Photon Count Statistics.ipynb',
#  'CCDs - Count Statistics - Exercise.ipynb',
#  'SNR Investigation Continued (answer key 1).ipynb',
#  'CCDReductionLabExercise.ipynb',
#  'Shifting.ipynb',
#  'DataReduction_SingleFrame_exercise.ipynb',
#  'pytest.ini',
#  'SNR Investigation Continued (answer key two).ipynb',
#  'Observation Planning - Space-Based.ipynb',
#  'Observation Planning Part 2 Exercise.ipynb',
#  'Observation Planning - Space-based - Exercise.ipynb']

# %% [markdown]
# What about _changing_ directories?
#
# For the purpose of this exercise, we'll make a new directory called `new_directory` and "move" into it:

# %%
os.mkdir('new_directory')

# %% [markdown]
# we move into it using the "change directory" (`cd` or `chdir`) command:

# %%
os.chdir('new_directory/')

# %% [markdown]
# now we can see that we've moved to a different place

# %%
os.getcwd()
# Out:
# '/home/runner/work/AST3722_Public_Materials/AST3722_Public_Materials/executed.workdir/new_directory'

# %% [markdown]
# There's nothing in this directory:

# %%
os.listdir()
# Out:
# []

# %% [markdown]
# So, what if we want to move something from another directory here?  Say, we want to move `new_file.txt` here.
#
# First, we have to understand a little about the directory tree.
#
# We are in a "branch" of the directory tree.  There are no _subdirectories_ below our current location: there are no folders inside the folder we're in.
#
# The folder we're in right now (`new_directory`) is sitting inside (or below) the directory we started in.  `new_directory` is a _subdirectory_ of wherever we started (the `starting_cwd` from above.
#
# We have two ways we can interact with files in the parent directory:
#
# 1. We can use the _absolute path_.  Absolute paths are things that look like `/Users/adam/directory/new_directory`: they start with a `/`, a forward-slash.  We can use `starting_cwd` for this.
# 2. We can use a _relative_ path.  Relative paths are any paths that start without a slash.  There are two special relative paths:
#   * `./` or `.` is the current directory.  It's not used much.
#   * `../` or `..` is the _parent_ directory.  It's used very often!
#
# So, we will list the contents of the starting directory now:

# %%
os.listdir(starting_cwd)
# Out:
# ['Planet Observation Planning.ipynb',
#  'EXECUTED_BRANCH.md',
#  'notebooks.toml',
#  'LongOrShortAnswerKey.ipynb',
#  '.gitignore',
#  'DataReduction_SingleFrame_exercise_filled.ipynb',
#  'Observation Planning Part 3 Exercise.ipynb',
#  'DirectoryStructure.ipynb',
#  'DataReductionWalkthrough.ipynb',
#  'Observation Planning Exercise.ipynb',
#  'SNR Investigation Continued.ipynb',
#  'Observation Planning Part 2.ipynb',
#  'Fitting - Simple Version.ipynb',
#  'Long Exposures or Short Exposures.ipynb',
#  'Observation Planning.ipynb',
#  'Detector Characterization (CCD) - Bias and Darks.ipynb',
#  'tests',
#  '.github',
#  'Observation Planning Part 3.ipynb',
#  'tools',
#  'new_directory',
#  'README.md',
#  'Detector Characterization (CMOS) - Bias, Darks, Gain, Flats.ipynb',
#  'AltAzcalculations.ipynb',
#  'new_file.txt',
#  'CCDs Overview - Data Reduction.ipynb',
#  'requirements-test.txt',
#  'requirements.txt',
#  'MachineReadableTables.ipynb',
#  'CCDs - Photon Count Statistics.ipynb',
#  'CCDs - Count Statistics - Exercise.ipynb',
#  'SNR Investigation Continued (answer key 1).ipynb',
#  'CCDReductionLabExercise.ipynb',
#  'Shifting.ipynb',
#  'DataReduction_SingleFrame_exercise.ipynb',
#  'pytest.ini',
#  'SNR Investigation Continued (answer key two).ipynb',
#  'Observation Planning - Space-Based.ipynb',
#  'Observation Planning Part 2 Exercise.ipynb',
#  'Observation Planning - Space-based - Exercise.ipynb']

# %%
os.listdir('../')
# Out:
# ['Planet Observation Planning.ipynb',
#  'EXECUTED_BRANCH.md',
#  'notebooks.toml',
#  'LongOrShortAnswerKey.ipynb',
#  '.gitignore',
#  'DataReduction_SingleFrame_exercise_filled.ipynb',
#  'Observation Planning Part 3 Exercise.ipynb',
#  'DirectoryStructure.ipynb',
#  'DataReductionWalkthrough.ipynb',
#  'Observation Planning Exercise.ipynb',
#  'SNR Investigation Continued.ipynb',
#  'Observation Planning Part 2.ipynb',
#  'Fitting - Simple Version.ipynb',
#  'Long Exposures or Short Exposures.ipynb',
#  'Observation Planning.ipynb',
#  'Detector Characterization (CCD) - Bias and Darks.ipynb',
#  'tests',
#  '.github',
#  'Observation Planning Part 3.ipynb',
#  'tools',
#  'new_directory',
#  'README.md',
#  'Detector Characterization (CMOS) - Bias, Darks, Gain, Flats.ipynb',
#  'AltAzcalculations.ipynb',
#  'new_file.txt',
#  'CCDs Overview - Data Reduction.ipynb',
#  'requirements-test.txt',
#  'requirements.txt',
#  'MachineReadableTables.ipynb',
#  'CCDs - Photon Count Statistics.ipynb',
#  'CCDs - Count Statistics - Exercise.ipynb',
#  'SNR Investigation Continued (answer key 1).ipynb',
#  'CCDReductionLabExercise.ipynb',
#  'Shifting.ipynb',
#  'DataReduction_SingleFrame_exercise.ipynb',
#  'pytest.ini',
#  'SNR Investigation Continued (answer key two).ipynb',
#  'Observation Planning - Space-Based.ipynb',
#  'Observation Planning Part 2 Exercise.ipynb',
#  'Observation Planning - Space-based - Exercise.ipynb']

# %% [markdown]
# You can chain together relative paths.  For example, `../../` means "two directories above this one".
#
# There's also another special way to refer to the directory we're in.  Since we're in a directory called `new_directory`, this: `../new_directory` is the same thing as `./` - both refer to _here_, the cwd.

# %% [markdown]
# How do we move a file from another directory to the current directory?
#
# We can use `shutil.move`.
#
# `shutil.move` can be used to rename a file (e.g., from "a.txt" to "b.txt") or to move a file from one location to another.
#
# It takes two arguments: the source `src` and the destination `dst`.  `shutil.move(src="source.txt", dst="destination.txt")`, for example.
#
# `dst`, the destination, can be a directory.
#
# We want to move `new_file.txt` from the parent directory (`../`) to here (`./`), so:

# %%
import shutil

# %%
shutil.move('../new_file.txt', './')
# Out:
# './new_file.txt'

# %% [markdown]
# Now we can check that the file is here:

# %%
os.listdir('.')
# Out:
# ['new_file.txt']

# %% [markdown]
# It is!

# %% [markdown]
# Now, if we want to move _multiple_ files from one source to the same destination, we can use a loop.
#
# For example:
#
# ```python
# import glob
# for fn in glob.glob("../*.FIT"):
#     shutil.move(fn, '.')
# ```

# %% [markdown]
# # Error Messages & File Access
#
# If you try to access a file that doesn't exist, you'll get some sort of error message.
#
# For example:

# %%
from astropy.io import fits

# %%
fits.open("this_is_not_a_real_file")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 fits.open("this_is_not_a_real_file")
#
# File /opt/hostedtoolcache/Python/3.13.15/x64/lib/python3.13/site-packages/astropy/io/fits/hdu/hdulist.py:227, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#     224 if not name:
#     225     raise ValueError(f"Empty filename: {name!r}")
# --> 227 return HDUList.fromfile(
#     228     name,
#     229     mode,
#     230     memmap,
#     231     save_backup,
#     232     cache,
#     233     lazy_load_hdus,
#     234     ignore_missing_simple,
#     235     use_fsspec=use_fsspec,
#     236     fsspec_kwargs=fsspec_kwargs,
#     237     decompress_in_memory=decompress_in_memory,
#     238     **kwargs,
#     239 )
#
# File /opt/hostedtoolcache/Python/3.13.15/x64/lib/python3.13/site-packages/astropy/io/fits/hdu/hdulist.py:491, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     472 @classmethod
#     473 def fromfile(
#     474     cls,
#    (...)    482     **kwargs,
#     483 ):
#     484     """
#     485     Creates an `HDUList` instance from a file-like object.
#     486
#    (...)    489     documentation for details of the parameters accepted by this method).
#     490     """
# --> 491     return cls._readfrom(
#     492         fileobj=fileobj,
#     493         mode=mode,
#     494         memmap=memmap,
#     495         save_backup=save_backup,
#     496         cache=cache,
#     497         ignore_missing_simple=ignore_missing_simple,
#     498         lazy_load_hdus=lazy_load_hdus,
#     499         **kwargs,
#     500     )
#
# File /opt/hostedtoolcache/Python/3.13.15/x64/lib/python3.13/site-packages/astropy/io/fits/hdu/hdulist.py:1193, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#    1190 if fileobj is not None:
#    1191     if not isinstance(fileobj, _File):
#    1192         # instantiate a FITS file object (ffo)
# -> 1193         fileobj = _File(
#    1194             fileobj,
#    1195             mode=mode,
#    1196             memmap=memmap,
#    1197             cache=cache,
#    1198             use_fsspec=use_fsspec,
#    1199             fsspec_kwargs=fsspec_kwargs,
#    1200             decompress_in_memory=decompress_in_memory,
#    1201         )
#    1202     # The Astropy mode is determined by the _File initializer if the
#    1203     # supplied mode was None
#    1204     mode = fileobj.mode
#
# File /opt/hostedtoolcache/Python/3.13.15/x64/lib/python3.13/site-packages/astropy/io/fits/file.py:239, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache, use_fsspec, fsspec_kwargs, decompress_in_memory)
#     237     self._open_fileobj(fileobj, mode, overwrite)
#     238 elif isinstance(fileobj, (str, bytes)):
# --> 239     self._open_filename(fileobj, mode, overwrite)
#     240 else:
#     241     self._open_filelike(fileobj, mode, overwrite)
#
# File /opt/hostedtoolcache/Python/3.13.15/x64/lib/python3.13/site-packages/astropy/io/fits/file.py:711, in _File._open_filename(self, filename, mode, overwrite)
#     708 ext = os.path.splitext(self.name)[1]
#     710 if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 711     self._file = open(self.name, IO_FITS_MODES[mode])
#     712     self.close_on_error = True
#     714 # Make certain we're back at the beginning of the file
#     715 # BZ2File does not support seek when the file is open for writing, but
#     716 # when opening a file for write, bz2.BZ2File always truncates anyway.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'this_is_not_a_real_file'

# %% [markdown]
# The error `FileNotFoundError: [Errno 2] No such file or directory: 'this_is_not_a_real_file'` tells you there is no file by that name.
#
# What if there is a file by that name, but you're still getting the error?  Usually that means the file is in a different directory.
#
# Let's go back to our original directory and try to access `new_file.txt`:

# %%
os.chdir(starting_cwd)

# %%
with open("new_file.txt", "r") as fh:
    print(fh.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 with open("new_file.txt", "r") as fh:
#       2     print(fh.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'new_file.txt'

# %% [markdown]
# Again, we get the error `FileNotFoundError: [Errno 2] No such file or directory: 'new_file.txt'`.
#
# But that file exists!  It's just in a different directory now.  It's in `new_directory/`, so its correct path is `new_directory/new_file.txt`:

# %%
with open("new_directory/new_file.txt", "r") as fh:
    print(fh.read())
# Out:
# This is a new file
